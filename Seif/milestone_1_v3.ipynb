# %%
import pandas as pd

# %%
asr=pd.read_csv('AirlineScrappedReview_Cleaned.csv')

# %%
asr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3575 entries, 0 to 3574
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Passanger_Name   3500 non-null   object
#  1   Flying_Date      955 non-null    object
#  2   Route            2807 non-null   object
#  3   Rating           3501 non-null   float64
#  4   Verified         3501 non-null   object
#  5   Review_title     3501 non-null   object
#  6   Review_content   3501 non-null   object
#  7   Traveller_Type   3501 non-null   object
#  8   Class            3501 non-null   object
#  9   Start_Location   2807 non-null   object
#  10  End_Location     2807 non-null   object
#  11  Layover_Route    484 non-null    object
#  12  Start_Latitude   3441 non-null   float64
#  13  Start_Longitude  3441 non-null   float64
#  14  Start_Address    3441 non-null   object
#  15  End_Latitude     3402 non-null   float64
#  16  End_Longitude    3402 non-null   float64
#  17  End_Address      3402 non-null   object
# dtypes: float64(5), object(13)
# memory usage: 502.9+ KB

# %%
asr = asr.dropna(how='all')

# %%
asr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3501 entries, 0 to 3500
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Passanger_Name   3500 non-null   object
#  1   Flying_Date      955 non-null    object
#  2   Route            2807 non-null   object
#  3   Rating           3501 non-null   float64
#  4   Verified         3501 non-null   object
#  5   Review_title     3501 non-null   object
#  6   Review_content   3501 non-null   object
#  7   Traveller_Type   3501 non-null   object
#  8   Class            3501 non-null   object
#  9   Start_Location   2807 non-null   object
#  10  End_Location     2807 non-null   object
#  11  Layover_Route    484 non-null    object
#  12  Start_Latitude   3441 non-null   float64
#  13  Start_Longitude  3441 non-null   float64
#  14  Start_Address    3441 non-null   object
#  15  End_Latitude     3402 non-null   float64
#  16  End_Longitude    3402 non-null   float64
#  17  End_Address      3402 non-null   object
# dtypes: float64(5), object(13)
# memory usage: 519.7+ KB

# %%
asr_with_no_route_and_start_address_and_end_address = asr[asr['Route'].isnull() & asr['Start_Address'].notnull() & asr['End_Address'].notnull()][['Route','Start_Address','End_Address']]

# %%
print(len(asr_with_no_route_and_start_address_and_end_address))
print(asr_with_no_route_and_start_address_and_end_address.head())
# Out:
# 694
#      Route                                      Start_Address  \
# 42     NaN  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 234    NaN  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 419    NaN  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2550   NaN  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2565   NaN  Nanno, Ville d'Anaunia, Comunità della Val di ...
#
#                                             End_Address
# 42    Nanno, Ville d'Anaunia, Comunità della Val di ...
# 234   Nanno, Ville d'Anaunia, Comunità della Val di ...
# 419   Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2550  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2565  Nanno, Ville d'Anaunia, Comunità della Val di ...

# %%
asr_with_no_route_and_start_address_and_end_address['Start_Address'].value_counts()
# Out:
# Start_Address
# Nanno, Ville d'Anaunia, Comunità della Val di Non, Provincia di Trento, Trentino-Alto Adige/Südtirol, 38093, Italia    694
# Name: count, dtype: int64

# %%
asr_with_no_route_and_start_address_and_end_address['End_Address'].value_counts()
# Out:
# End_Address
# Nanno, Ville d'Anaunia, Comunità della Val di Non, Provincia di Trento, Trentino-Alto Adige/Südtirol, 38093, Italia    694
# Name: count, dtype: int64

# %%
asr2=asr.copy()
asr_with_same_start_and_end_address=asr[(asr['Start_Address']==asr['End_Address'])]
asr2.drop(asr_with_same_start_and_end_address.index, inplace=True)

# %%
asr2_with_start_address_Italia=asr2[asr2['Start_Address'].eq("Nanno, Ville d'Anaunia, Comunità della Val di Non, Provincia di Trento, Trentino-Alto Adige/Südtirol, 38093, Italia")]

# %%
len(asr2_with_start_address_Italia)
# Out:
# 0

# %%
asr2_with_start_address_Italia.head()[['Start_Address','End_Address']]
# Out:
#                                          Start_Address  \
# 12   London Gatwick Airport, Perimeter Road East, L...
# 28      Las Vegas, Clark County, Nevada, United States
# 61     London, Greater London, England, United Kingdom
# 98   London Heathrow Airport, The Beacon Roundabout...
# 149    London, Greater London, England, United Kingdom
#
#                                            End_Address
# 12                Venezia, Veneto, 30121-30176, Italia
# 28                Venezia, Veneto, 30121-30176, Italia
# 61                Venezia, Veneto, 30121-30176, Italia
# 98   Aeroporto di Milano-Malpensa, Rental Car Retur...
# 149                 Roma, Roma Capitale, Lazio, Italia

# %%
# Let's examine the records where Start_Address equals End_Address
print(f"Number of records with same start and end address: {len(asr_with_same_start_and_end_address)}")
print("\nSample of these records:")
print(asr_with_same_start_and_end_address[['Start_Address', 'End_Address', 'Route']].head(10))
# Out:
# Number of records with same start and end address: 694
#
# Sample of these records:
#                                           Start_Address  \
# 42    Nanno, Ville d'Anaunia, Comunità della Val di ...
# 234   Nanno, Ville d'Anaunia, Comunità della Val di ...
# 419   Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2550  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2565  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2808  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2813  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2814  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2815  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2816  Nanno, Ville d'Anaunia, Comunità della Val di ...
#
#                                             End_Address Route
# 42    Nanno, Ville d'Anaunia, Comunità della Val di ...   NaN
# 234   Nanno, Ville d'Anaunia, Comunità della Val di ...   NaN
# 419   Nanno, Ville d'Anaunia, Comunità della Val di ...   NaN
# 2550  Nanno, Ville d'Anaunia, Comunità della Val di ...   NaN
# 2565  Nanno, Ville d'Anaunia, Comunità della Val di ...   NaN
# 2808  Nanno, Ville d'Anaunia, Comunità della Val di ...   NaN
# 2813  Nanno, Ville d'Anaunia, Comunità della Val di ...   NaN
# 2814  Nanno, Ville d'Anaunia, Comunità della Val di ...   NaN
# 2815  Nanno, Ville d'Anaunia, Comunità della Val di ...   NaN
# 2816  Nanno, Ville d'Anaunia, Comunità della Val di ...   NaN

# %% [markdown]
# ## Strategy for handling records with same Start_Address and End_Address
#
# Since these records have the same start and end location, we have a few options:
# 1. Mark them as "Invalid Route" or "Same Location"
# 2. Extract city/country from the address and create a route like "City-City" or "Country-Country"
# 3. Drop these records as they don't represent valid flight routes

# %%
# Option 1: Extract country from address and create route format
# Let's see what the addresses look like
def extract_country(address):
    """Extract the country (last part) from the address"""
    if pd.isna(address):
        return None
    # Country is typically the last part after the last comma
    parts = str(address).split(',')
    return parts[-1].strip() if parts else None

# Test on the same start/end address records
asr_with_same_start_and_end_address['Country'] = asr_with_same_start_and_end_address['Start_Address'].apply(extract_country)
print(asr_with_same_start_and_end_address['Country'].value_counts())
print("\nSample:")
print(asr_with_same_start_and_end_address[['Start_Address', 'Country']].head())
# Out:
# Country
# Italia    694
# Name: count, dtype: int64
#
# Sample:
#                                           Start_Address Country
# 42    Nanno, Ville d'Anaunia, Comunità della Val di ...  Italia
# 234   Nanno, Ville d'Anaunia, Comunità della Val di ...  Italia
# 419   Nanno, Ville d'Anaunia, Comunità della Val di ...  Italia
# 2550  Nanno, Ville d'Anaunia, Comunità della Val di ...  Italia
# 2565  Nanno, Ville d'Anaunia, Comunità della Val di ...  Italia
# C:\Users\Legion\AppData\Local\Temp\ipykernel_32224\2126533792.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asr_with_same_start_and_end_address['Country'] = asr_with_same_start_and_end_address['Start_Address'].apply(extract_country)

# %%
# Solution: Populate Route field for records with same start and end address
# For these cases, we'll create a route in the format "Country-Country" or mark as "Invalid Route"

# Method 1: Mark as "Same Location" or extract city information
def create_route_for_same_location(row):
    """Create a route identifier for records with same start/end"""
    if pd.isna(row['Start_Address']):
        return None
    
    # Extract city (usually second-to-last or third-to-last component)
    parts = str(row['Start_Address']).split(',')
    
    # Get country (last part)
    country = parts[-1].strip() if len(parts) > 0 else "Unknown"
    
    # Try to get city/region (work backwards to find meaningful location)
    city = parts[0].strip() if len(parts) > 0 else "Unknown"
    
    # Create route format: "City-City" to indicate same location
    return f"{city}-{city}"

# Apply to the original dataframe for rows with same start and end
mask = (asr['Start_Address'] == asr['End_Address']) & (asr['Start_Address'].notna())
asr.loc[mask, 'Route'] = asr.loc[mask].apply(create_route_for_same_location, axis=1)

# Check results
print(f"Updated {mask.sum()} records with same start and end address")
print("\nSample of updated routes:")
print(asr.loc[mask, ['Start_Address', 'End_Address', 'Route']].head(10))
# Out:
# Updated 694 records with same start and end address
#
# Sample of updated routes:
#                                           Start_Address  \
# 42    Nanno, Ville d'Anaunia, Comunità della Val di ...
# 234   Nanno, Ville d'Anaunia, Comunità della Val di ...
# 419   Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2550  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2565  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2808  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2813  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2814  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2815  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 2816  Nanno, Ville d'Anaunia, Comunità della Val di ...
#
#                                             End_Address        Route
# 42    Nanno, Ville d'Anaunia, Comunità della Val di ...  Nanno-Nanno
# 234   Nanno, Ville d'Anaunia, Comunità della Val di ...  Nanno-Nanno
# 419   Nanno, Ville d'Anaunia, Comunità della Val di ...  Nanno-Nanno
# 2550  Nanno, Ville d'Anaunia, Comunità della Val di ...  Nanno-Nanno
# 2565  Nanno, Ville d'Anaunia, Comunità della Val di ...  Nanno-Nanno
# 2808  Nanno, Ville d'Anaunia, Comunità della Val di ...  Nanno-Nanno
# 2813  Nanno, Ville d'Anaunia, Comunità della Val di ...  Nanno-Nanno
# 2814  Nanno, Ville d'Anaunia, Comunità della Val di ...  Nanno-Nanno
# 2815  Nanno, Ville d'Anaunia, Comunità della Val di ...  Nanno-Nanno
# 2816  Nanno, Ville d'Anaunia, Comunità della Val di ...  Nanno-Nanno

# %%
# Alternative: Mark them clearly as invalid/same location routes
# This might be more useful for filtering later

# You could also use:
# asr.loc[mask, 'Route'] = 'SAME_LOCATION'
# or
# asr.loc[mask, 'Route'] = 'Invalid Route'

# Verify the changes
print(f"\nTotal routes in dataset: {asr['Route'].notna().sum()}")
print(f"Routes populated for same start/end: {(asr['Route'] == 'Nanno-Nanno').sum()}")

# Check if there are other patterns
route_counts = asr[mask]['Route'].value_counts()
print(f"\nRoute patterns for same location records:")
print(route_counts)
# Out:
# Total routes in dataset: 3501
# Routes populated for same start/end: 694
#
# Route patterns for same location records:
# Route
# Nanno-Nanno    694
# Name: count, dtype: int64

# %% [markdown]
# ## Alternative Approaches for Same Location Routes
#
# If you prefer a different approach, here are alternatives:
#
# **Option 1: Mark as invalid (current approach modified)**
# ```python
# asr.loc[mask, 'Route'] = 'INVALID_SAME_LOCATION'
# ```
#
# **Option 2: Use country-based format**
# ```python
# asr.loc[mask, 'Route'] = 'Italia-Italia'
# ```
#
# **Option 3: Drop these records entirely**
# ```python
# asr = asr[~mask]  # Remove records with same start and end
# ```
#
# **Option 4: Flag them for manual review**
# ```python
# asr['is_same_location'] = mask
# # Keep original Route as NaN and filter later
# ```

# %% [markdown]
# ## Using NLP to Extract Routes from Review Content
#
# We can analyze the review text to extract origin and destination information using:
# 1. Pattern matching for common flight route phrases
# 2. Named Entity Recognition (NER) for location detection
# 3. Regex patterns for airport codes (e.g., LHR, JFK)

# %%
# First, let's check what columns are available and examine review content
print("Dataset columns:")
print(asr.columns.tolist())
print("\n" + "="*80)

# Check for review content column (might be named 'review', 'Review_Content', 'content', etc.)
review_columns = [col for col in asr.columns if 'review' in col.lower() or 'content' in col.lower() or 'text' in col.lower()]
print(f"\nPotential review columns: {review_columns}")

# Let's look at records with same start/end address and see their review content
if review_columns:
    review_col = review_columns[0]  # Use the first review column found
    print(f"\nUsing column: '{review_col}'")
    print("\nSample reviews from records with same start/end address:")
    sample_reviews = asr_with_same_start_and_end_address[[review_col]].head(5)
    for idx, row in sample_reviews.iterrows():
        print(f"\n--- Review {idx} ---")
        print(row[review_col][:500] if pd.notna(row[review_col]) else "No review text")
        print()
else:
    print("\nNo review content column found!")
# Out:
# Dataset columns:
# ['Passanger_Name', 'Flying_Date', 'Route', 'Rating', 'Verified', 'Review_title', 'Review_content', 'Traveller_Type', 'Class', 'Start_Location', 'End_Location', 'Layover_Route', 'Start_Latitude', 'Start_Longitude', 'Start_Address', 'End_Latitude', 'End_Longitude', 'End_Address']
#
# ================================================================================
#
# Potential review columns: ['Review_title', 'Review_content']
#
# Using column: 'Review_title'
#
# Sample reviews from records with same start/end address:
#
# --- Review 42 ---
# I had to reschedule my flight
#
#
# --- Review 234 ---
# do not allow free seat selection
#
#
# --- Review 419 ---
# no refund issued yet
#
#
# --- Review 2550 ---
# Fawlty Towers of customer service
#
#
# --- Review 2565 ---
# seats were extremely small

# %%
# Let's examine the Review_content column more closely
print("Sample Review_content from records with same start/end address:\n")
sample_with_content = asr_with_same_start_and_end_address[['Review_content', 'Start_Address', 'End_Address', 'Route']].head(10)

for idx, row in sample_with_content.iterrows():
    print(f"\n{'='*80}")
    print(f"Index: {idx}")
    print(f"Route: {row['Route']}")
    print(f"Start: {row['Start_Address'][:50]}...")
    print(f"\nReview Content:")
    print(row['Review_content'][:600] if pd.notna(row['Review_content']) else "No review content")
    print()
# Out:
# Sample Review_content from records with same start/end address:
#
#
# ================================================================================
# Index: 42
# Route: nan
# Start: Nanno, Ville d'Anaunia, Comunità della Val di Non,...
#
# Review Content:
# I booked business class tickets for my fiancé and I. I had to reschedule my flight due to an unforeseen timing change, so I called to get have my flight refunded. The representative on the phone informed me he wasn't sure how much I would get, as the refund department needed to check, but estimated I would lose 10-20% of my booking to fees. I accepted. I never got a cancellation email, or any update, but instead received $35 total back. Less than 1% of my booking costs. Since then I have spent over 5 hours calling different departments before they blocked me. I've lost a tremendous amount of m
#
#
# ================================================================================
# Index: 234
# Route: nan
# Start: Nanno, Ville d'Anaunia, Comunità della Val di Non,...
#
# Review Content:
# Second time getting poor service from BA. 1st, unable to contact via phone, email or website. 2nd even with four business class tickets across the Atlantic, they do not allow free seat selection or check in until 24 hours prior to the flight. Do they understand what the last 24 hours of an international trip are like? By the time we confirmed our seats my wife and our kids were spread throughout the plane. Of course no-one at the airport could do anything.
#
#
# ================================================================================
# Index: 419
# Route: nan
# Start: Nanno, Ville d'Anaunia, Comunità della Val di Non,...
#
# Review Content:
# Booked flight six months before travel, then month before the flight BA cancelled the flight giving the option to rebook for another day - bearing in mind that people have work and school that wasn't ideal on top of booked parking for over three weeks. We rebooked the flight- as suggested by them and a week later BA cancelled the rebooked flight. We were told that we will receive a refund within 10 working days. Over two weeks passed and I called again. I was informed that they can't give a time frame for processing refunds, and no refund issued yet. BA representative refuses to give contact d
#
#
# ================================================================================
# Index: 2550
# Route: nan
# Start: Nanno, Ville d'Anaunia, Comunità della Val di Non,...
#
# Review Content:
# My issue is the very poor British Airways customer relations service you receive once there is an issue, it is only then you see what BA really is. Following a dreadful experience trying to sort out a weekend in Paris I decided to complain to British Airways customer relations, that was the start of a nightmare and frustrating experience. BA customer service is like the Fawlty Towers of customer services! I have tried many times ringing, longest on hold before I hung up was 2hrs,  fastest through 45 mins. They only want to get you off the phone as quick as they can and keep apologising that th
#
#
# ================================================================================
# Index: 2565
# Route: nan
# Start: Nanno, Ville d'Anaunia, Comunità della Val di Non,...
#
# Review Content:
# The British Airways seats were extremely small, uncomfortable and did not operate properly. In order to recline the seat or return it to the upright position you had to do it manually. The bathrooms throughout the plane were dirty and smelly from the minute we boarded. The meals British Airways served were abysmal. On the way home from London to the U.S. passengers had the choice of a chicken curry dish with saffron rice or the vegetarian option. The smell of curry makes me nauseated so I opted for the vegetarian dish. I was served greasy, overly seasoned pasta soaked in oil and covered with a
#
#
# ================================================================================
# Index: 2808
# Route: nan
# Start: Nanno, Ville d'Anaunia, Comunità della Val di Non,...
#
# Review Content:
# This is more of a general review having travelled almost exclusively with BA longhaul as a family for the past 3-4 years. I highly rate BA for families. On our travels I have found the BA staff inflight: 1) To be sympathetic towards my wife and I with having infants. They have offered quiet areas during service (on the A380) to help settle our baby. Left us to last for dinner service if we were in the middle of settling the kids (nothing worse that being made to take a tray of food when all you want is your kids to sleep). 2) Friendly and attentive, but maintaining professionalism. Crew are no
#
#
# ================================================================================
# Index: 2813
# Route: nan
# Start: Nanno, Ville d'Anaunia, Comunità della Val di Non,...
#
# Review Content:
# Family of 3 - 747 out (upper deck) 777 back. Fortunate to be a silver member so get to allocate seats when booking. Flights on-time out, 1 hour delay on return, reason late inbound aircraft (really useless excuse). On departure no knowledge of which gates would be used for this and many other flights so both main lounges by security in T5 hellishly overcrowded. Assume the remote lounges would have been empty. 747 tired with ancient entertainment system but quiet upper deck, 777 the same except crowded and busy on the only deck - although both did have new first class so some upgrading had occu
#
#
# ================================================================================
# Index: 2814
# Route: nan
# Start: Nanno, Ville d'Anaunia, Comunità della Val di Non,...
#
# Review Content:
# Travelled from Venice to Gatwick on 28th May check in staff rude and unhelpful plane seats and food trays dirty and seats very worn and uncomfortable. Lady next to me had her arm rest fall off during the flight. Food for my daughter inedible. Attendants very lacklustre. Nappy changing table fell on my mum whilst on the toilet attendant suggested we sue BA! Wrote to BA to complain got fobbing off email in return. Won't be wasting my money on business class again. Shocking service and standards from start to finish.
#
#
# ================================================================================
# Index: 2815
# Route: nan
# Start: Nanno, Ville d'Anaunia, Comunità della Val di Non,...
#
# Review Content:
# Worst customer experience on BA flight. I have a confirmed flights for British Airways from Singapore to Sydney for tomorrow. When I tried to check online the system did not allow me to do online check-in. I called the BA contact center in the UK and was shocked with the response received. The person told me that there is a difference between confirmed booking and confirmed seating. Essentially BA wants to sell their seats at a premium. They arm twist the passengers and make lame excuses that although you have confirmed flight bookings it doesn't mean you can fly unless you get the seats alloc
#
#
# ================================================================================
# Index: 2816
# Route: nan
# Start: Nanno, Ville d'Anaunia, Comunità della Val di Non,...
#
# Review Content:
# I had this terrible experience of traveling British Airways from Heathrow to Calgary. The plane was parked in a no-mans area and we were bussed to the plane. To my horror I had to climb through the stairs with my carry on bag! The width of the seat and the leg space is the smallest I saw in my 40 years of travel experience. It's a shame that that the airline is using this kind of carrier for a Transatlantic flight. The quality of food is one of the worst I have ever seen. I picked the non-veg chicken item the taste and content was hopeless. The container was marked for expiry as 28/11/16 07.53

# %%
# Let's create NLP-based route extraction functions
import re

def extract_route_patterns(text):
    """Extract route information from review text using pattern matching"""
    if pd.isna(text):
        return None, None, None
    
    text = str(text).lower()
    
    # Pattern 1: "from X to Y" or "X to Y"
    pattern1 = r'(?:from|flying from)\s+([A-Za-z\s]+?)\s+to\s+([A-Za-z\s]+?)(?:\s|\.|\,|$)'
    
    # Pattern 2: Airport codes (3 letters uppercase)
    pattern2 = r'\b([A-Z]{3})\b.*?\b([A-Z]{3})\b'
    
    # Pattern 3: "London to Paris" style
    pattern3 = r'\b([A-Z][a-z]+(?:\s[A-Z][a-z]+)?)\s+to\s+([A-Z][a-z]+(?:\s[A-Z][a-z]+)?)\b'
    
    # Try pattern matching on original case text
    original_text = str(text)
    
    # Try airport codes first (most reliable)
    match_codes = re.search(pattern2, original_text)
    if match_codes:
        return match_codes.group(1), match_codes.group(2), 'airport_code'
    
    # Try city names pattern
    match_cities = re.search(pattern3, original_text)
    if match_cities:
        return match_cities.group(1).strip(), match_cities.group(2).strip(), 'city_name'
    
    # Try "from X to Y" pattern
    match_from_to = re.search(pattern1, text)
    if match_from_to:
        return match_from_to.group(1).strip(), match_from_to.group(2).strip(), 'from_to_pattern'
    
    return None, None, None

# Test on a sample
print("Testing route extraction on sample reviews:\n")
test_sample = asr_with_same_start_and_end_address[['Review_content']].head(20)

for idx, row in test_sample.iterrows():
    origin, destination, pattern_type = extract_route_patterns(row['Review_content'])
    if origin or destination:
        print(f"Index {idx}: {origin} → {destination} (matched: {pattern_type})")
        print(f"  Review snippet: {str(row['Review_content'])[:100]}...")
        print()
# Out:
# Testing route extraction on sample reviews:
#
# Index 2565: london → the (matched: from_to_pattern)
#   Review snippet: The British Airways seats were extremely small, uncomfortable and did not operate properly. In order...
#
# Index 2814: venice → gatwick (matched: from_to_pattern)
#   Review snippet: Travelled from Venice to Gatwick on 28th May check in staff rude and unhelpful plane seats and food ...
#
# Index 2815: singapore → sydney (matched: from_to_pattern)
#   Review snippet: Worst customer experience on BA flight. I have a confirmed flights for British Airways from Singapor...
#
# Index 2816: heathrow → calgary (matched: from_to_pattern)
#   Review snippet: I had this terrible experience of traveling British Airways from Heathrow to Calgary. The plane was ...
#
# Index 2818: heathrow → tokyo (matched: from_to_pattern)
#   Review snippet: I flew from Heathrow to Tokyo Haneda in First. The Concorde Lounge at Heathrow was quite good though...
#
# Index 2822: heathrow → san (matched: from_to_pattern)
#   Review snippet: Flew from Heathrow to San Francisco on May 1st with BA. What a disappointment! I had to pay over £12...

# %%
# Apply route extraction to ALL records with same start/end address
print("Applying NLP extraction to all records with same start/end address...\n")

# Extract routes from review content
extraction_results = asr_with_same_start_and_end_address['Review_content'].apply(extract_route_patterns)

# Split into separate columns
asr_with_same_start_and_end_address['extracted_origin'] = extraction_results.apply(lambda x: x[0])
asr_with_same_start_and_end_address['extracted_destination'] = extraction_results.apply(lambda x: x[1])
asr_with_same_start_and_end_address['extraction_method'] = extraction_results.apply(lambda x: x[2])

# Count how many we successfully extracted
successful_extractions = asr_with_same_start_and_end_address[
    asr_with_same_start_and_end_address['extracted_origin'].notna()
]

print(f"Total records with same start/end: {len(asr_with_same_start_and_end_address)}")
print(f"Successfully extracted routes: {len(successful_extractions)}")
print(f"Success rate: {len(successful_extractions)/len(asr_with_same_start_and_end_address)*100:.1f}%")

print("\n" + "="*80)
print("Sample of successfully extracted routes:")
print("="*80)
sample_extracted = successful_extractions[['extracted_origin', 'extracted_destination', 'extraction_method', 'Review_content']].head(10)
for idx, row in sample_extracted.iterrows():
    print(f"\nIndex {idx}:")
    print(f"  Extracted Route: {row['extracted_origin']} → {row['extracted_destination']}")
    print(f"  Method: {row['extraction_method']}")
    print(f"  Review: {str(row['Review_content'])[:150]}...")
    print()
# Out:
# Applying NLP extraction to all records with same start/end address...
#
# Total records with same start/end: 694
# Successfully extracted routes: 174
# Success rate: 25.1%
#
# ================================================================================
# Sample of successfully extracted routes:
# ================================================================================
#
# Index 2565:
#   Extracted Route: london → the
#   Method: from_to_pattern
#   Review: The British Airways seats were extremely small, uncomfortable and did not operate properly. In order to recline the seat or return it to the upright p...
#
#
# Index 2814:
#   Extracted Route: venice → gatwick
#   Method: from_to_pattern
#   Review: Travelled from Venice to Gatwick on 28th May check in staff rude and unhelpful plane seats and food trays dirty and seats very worn and uncomfortable....
#
#
# Index 2815:
#   Extracted Route: singapore → sydney
#   Method: from_to_pattern
#   Review: Worst customer experience on BA flight. I have a confirmed flights for British Airways from Singapore to Sydney for tomorrow. When I tried to check on...
#
#
# Index 2816:
#   Extracted Route: heathrow → calgary
#   Method: from_to_pattern
#   Review: I had this terrible experience of traveling British Airways from Heathrow to Calgary. The plane was parked in a no-mans area and we were bussed to the...
#
#
# Index 2818:
#   Extracted Route: heathrow → tokyo
#   Method: from_to_pattern
#   Review: I flew from Heathrow to Tokyo Haneda in First. The Concorde Lounge at Heathrow was quite good though I was surprised by how little choice there was wh...
#
#
# Index 2822:
#   Extracted Route: heathrow → san
#   Method: from_to_pattern
#   Review: Flew from Heathrow to San Francisco on May 1st with BA. What a disappointment! I had to pay over £120 to sit next to my husband having already paid fo...
#
#
# Index 2828:
#   Extracted Route: heathrow → singapore
#   Method: from_to_pattern
#   Review: We travelled on Flight BA11 from Heathrow to Singapore on 25th July 2014 and it is most unlikely we would travel with them again. We were supposed to ...
#
#
# Index 2834:
#   Extracted Route: ewr → lhr
#   Method: from_to_pattern
#   Review: First off this particular flight from EWR to LHR and back was advertised as a Boeing 787 Dreamliner. The actual jet was a 777 much less comfortable. T...
#
#
# Index 2836:
#   Extracted Route: the cabin crew who almost without exception appeared uninterested in customer service → the
#   Method: from_to_pattern
#   Review: BA 10 Bangkok to London Heathrow May 26th 2015 World Traveller Plus (Premium Economy). First the positives: check-in at BKK was reasonably efficient t...
#
#
# Index 2850:
#   Extracted Route: dublin → muscat
#   Method: from_to_pattern
#   Review: Flight BA72 and BA73. Departed 14th May returned 20th May 2015. Very impressed with flight and cabin service on our trip from Dublin to Muscat Oman bo...
# C:\Users\Legion\AppData\Local\Temp\ipykernel_32224\3283536208.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asr_with_same_start_and_end_address['extracted_origin'] = extraction_results.apply(lambda x: x[0])
# C:\Users\Legion\AppData\Local\Temp\ipykernel_32224\3283536208.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asr_with_same_start_and_end_address['extracted_destination'] = extraction_results.apply(lambda x: x[1])
# C:\Users\Legion\AppData\Local\Temp\ipykernel_32224\3283536208.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asr_with_same_start_and_end_address['extraction_method'] = extraction_results.apply(lambda x: x[2])

# %%
# Let's properly apply this to the main dataframe and get summary statistics
# Work on the original dataframe to avoid SettingWithCopyWarning

# First, let's identify the indices of records we can extract routes from
mask_same_location = (asr['Start_Address'] == asr['End_Address']) & (asr['Start_Address'].notna())

# Apply extraction function
print("Extracting routes from review content for records with same start/end address...")
extraction_results = asr.loc[mask_same_location, 'Review_content'].apply(extract_route_patterns)

# Create new columns in the main dataframe
asr.loc[mask_same_location, 'NLP_extracted_origin'] = extraction_results.apply(lambda x: x[0])
asr.loc[mask_same_location, 'NLP_extracted_destination'] = extraction_results.apply(lambda x: x[1])
asr.loc[mask_same_location, 'NLP_extraction_method'] = extraction_results.apply(lambda x: x[2])

# Count successful extractions
successful_mask = mask_same_location & asr['NLP_extracted_origin'].notna()
num_successful = successful_mask.sum()

print(f"\n{'='*80}")
print("EXTRACTION SUMMARY")
print(f"{'='*80}")
print(f"Total records with same Start/End address: {mask_same_location.sum()}")
print(f"Successfully extracted routes from reviews: {num_successful}")
print(f"Success rate: {(num_successful/mask_same_location.sum())*100:.1f}%")
print(f"Records that still need attention: {mask_same_location.sum() - num_successful}")
print(f"{'='*80}\n")
# Out:
# Extracting routes from review content for records with same start/end address...
#
# ================================================================================
# EXTRACTION SUMMARY
# ================================================================================
# Total records with same Start/End address: 694
# Successfully extracted routes from reviews: 174
# Success rate: 25.1%
# Records that still need attention: 520
# ================================================================================

# %%
# Now let's update the Route field with the extracted information
# and also try to populate Start_Address and End_Address based on extracted cities

# Show samples of what we extracted
print("Sample of successfully extracted routes:\n")
successful_extractions = asr[successful_mask][['Review_content', 'NLP_extracted_origin', 
                                                 'NLP_extracted_destination', 'NLP_extraction_method',
                                                 'Route', 'Start_Address', 'End_Address']].head(15)

for idx, row in successful_extractions.iterrows():
    print(f"Index {idx}:")
    print(f"  Extracted: {row['NLP_extracted_origin']} → {row['NLP_extracted_destination']}")
    print(f"  Method: {row['NLP_extraction_method']}")
    print(f"  Current Route: {row['Route']}")
    print(f"  Review: {str(row['Review_content'])[:120]}...")
    print()
# Out:
# Sample of successfully extracted routes:
#
# Index 2565:
#   Extracted: london → the
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: The British Airways seats were extremely small, uncomfortable and did not operate properly. In order to recline the seat...
#
# Index 2814:
#   Extracted: venice → gatwick
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: Travelled from Venice to Gatwick on 28th May check in staff rude and unhelpful plane seats and food trays dirty and seat...
#
# Index 2815:
#   Extracted: singapore → sydney
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: Worst customer experience on BA flight. I have a confirmed flights for British Airways from Singapore to Sydney for tomo...
#
# Index 2816:
#   Extracted: heathrow → calgary
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: I had this terrible experience of traveling British Airways from Heathrow to Calgary. The plane was parked in a no-mans ...
#
# Index 2818:
#   Extracted: heathrow → tokyo
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: I flew from Heathrow to Tokyo Haneda in First. The Concorde Lounge at Heathrow was quite good though I was surprised by ...
#
# Index 2822:
#   Extracted: heathrow → san
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: Flew from Heathrow to San Francisco on May 1st with BA. What a disappointment! I had to pay over £120 to sit next to my ...
#
# Index 2828:
#   Extracted: heathrow → singapore
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: We travelled on Flight BA11 from Heathrow to Singapore on 25th July 2014 and it is most unlikely we would travel with th...
#
# Index 2834:
#   Extracted: ewr → lhr
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: First off this particular flight from EWR to LHR and back was advertised as a Boeing 787 Dreamliner. The actual jet was ...
#
# Index 2836:
#   Extracted: the cabin crew who almost without exception appeared uninterested in customer service → the
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: BA 10 Bangkok to London Heathrow May 26th 2015 World Traveller Plus (Premium Economy). First the positives: check-in at ...
#
# Index 2850:
#   Extracted: dublin → muscat
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: Flight BA72 and BA73. Departed 14th May returned 20th May 2015. Very impressed with flight and cabin service on our trip...
#
# Index 2851:
#   Extracted: starter → dessert
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: YYZ-LHR-BRU: First - Club World: Check-in in Toronto was smooth with very nice and friendly ground staff. Used pre-dinin...
#
# Index 2852:
#   Extracted: barbados → london
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: Travelled with my wife from Barbados to London Gatwick on Tuesday's overnight flight. Boarding by row numbers was well c...
#
# Index 2855:
#   Extracted: the austin → heathrow
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: Our flight on economy long distance from the Austin to Heathrow was the most uncomfortable we've had on any carrier and ...
#
# Index 2857:
#   Extracted: heathrow → washington
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: Travelled from Heathrow to Washington in April on one of the new A380 planes. Extremely impressed with the plane even in...
#
# Index 2859:
#   Extracted: lisbon with a remote boarding location and poor management prior → boarding
#   Method: from_to_pattern
#   Current Route: Nanno-Nanno
#   Review: Brilliant service from the cabin crew and Captain/First Officer on this much delayed Lisbon-LHR flight. BA have question...

# %%
# Update the Route field with NLP-extracted information
# Format: "Origin-Destination" based on extracted cities/airports

def format_route(origin, destination):
    """Format extracted origin and destination into route format"""
    if pd.isna(origin) or pd.isna(destination):
        return None
    origin = str(origin).strip().title()
    destination = str(destination).strip().title()
    return f"{origin}-{destination}"

# Update Route for successfully extracted records
asr.loc[successful_mask, 'Route'] = asr.loc[successful_mask].apply(
    lambda row: format_route(row['NLP_extracted_origin'], row['NLP_extracted_destination']), 
    axis=1
)

print("✓ Updated Route field with NLP-extracted information")
print(f"  → {successful_mask.sum()} routes updated\n")

# Show breakdown of extraction methods
print("Extraction methods used:")
print(asr[successful_mask]['NLP_extraction_method'].value_counts())
print("\n" + "="*80)

# Show sample of updated routes
print("\nSample of updated Route field:")
print(asr[successful_mask][['NLP_extracted_origin', 'NLP_extracted_destination', 'Route']].head(10))
# Out:
# ✓ Updated Route field with NLP-extracted information
#   → 174 routes updated
#
# Extraction methods used:
# NLP_extraction_method
# from_to_pattern    174
# Name: count, dtype: int64
#
# ================================================================================
#
# Sample of updated Route field:
#                                    NLP_extracted_origin  \
# 2565                                             london
# 2814                                             venice
# 2815                                          singapore
# 2816                                           heathrow
# 2818                                           heathrow
# 2822                                           heathrow
# 2828                                           heathrow
# 2834                                                ewr
# 2836  the cabin crew who almost without exception ap...
# 2850                                             dublin
#
#      NLP_extracted_destination  \
# 2565                       the
# 2814                   gatwick
# 2815                    sydney
# 2816                   calgary
# 2818                     tokyo
# 2822                       san
# 2828                 singapore
# 2834                       lhr
# 2836                       the
# 2850                    muscat
#
#                                                   Route
# 2565                                         London-The
# 2814                                     Venice-Gatwick
# 2815                                   Singapore-Sydney
# 2816                                   Heathrow-Calgary
# 2818                                     Heathrow-Tokyo
# 2822                                       Heathrow-San
# 2828                                 Heathrow-Singapore
# 2834                                            Ewr-Lhr
# 2836  The Cabin Crew Who Almost Without Exception Ap...
# 2850                                      Dublin-Muscat

# %%
# Final summary: Show which rows we can confidently work with
print("="*80)
print("FINAL NLP EXTRACTION REPORT")
print("="*80)

# Get the row indices that were successfully extracted
extracted_indices = asr[successful_mask].index.tolist()

print(f"\n✓ Successfully extracted route information from review content")
print(f"  Total problematic records (same start/end): {mask_same_location.sum()}")
print(f"  Successfully extracted via NLP: {len(extracted_indices)}")
print(f"  Success rate: {(len(extracted_indices)/mask_same_location.sum())*100:.1f}%")
print(f"  Remaining records needing attention: {mask_same_location.sum() - len(extracted_indices)}")

print(f"\n{'='*80}")
print("ROW INDICES WITH SUCCESSFULLY EXTRACTED ROUTES:")
print(f"{'='*80}")
print(f"Total: {len(extracted_indices)} rows")
print(f"\nFirst 50 indices: {extracted_indices[:50]}")
print(f"...")
print(f"Last 10 indices: {extracted_indices[-10:]}")

# Save the successfully extracted indices for future reference
print(f"\n{'='*80}")
print("You can access these records using:")
print(f"  asr.loc[{extracted_indices[:5]}]  # Example for first 5")
print(f"  OR use the mask: asr[successful_mask]")
print(f"{'='*80}")
# Out:
# ================================================================================
# FINAL NLP EXTRACTION REPORT
# ================================================================================
#
# ✓ Successfully extracted route information from review content
#   Total problematic records (same start/end): 694
#   Successfully extracted via NLP: 174
#   Success rate: 25.1%
#   Remaining records needing attention: 520
#
# ================================================================================
# ROW INDICES WITH SUCCESSFULLY EXTRACTED ROUTES:
# ================================================================================
# Total: 174 rows
#
# First 50 indices: [2565, 2814, 2815, 2816, 2818, 2822, 2828, 2834, 2836, 2850, 2851, 2852, 2855, 2857, 2859, 2860, 2863, 2866, 2869, 2874, 2875, 2877, 2878, 2883, 2886, 2890, 2894, 2897, 2904, 2913, 2916, 2917, 2921, 2925, 2927, 2936, 2941, 2946, 2947, 2953, 2956, 2959, 2963, 2966, 2967, 2974, 2980, 2983, 2984, 2985]
# ...
# Last 10 indices: [3467, 3469, 3476, 3477, 3491, 3493, 3495, 3496, 3497, 3498]
#
# ================================================================================
# You can access these records using:
#   asr.loc[[2565, 2814, 2815, 2816, 2818]]  # Example for first 5
#   OR use the mask: asr[successful_mask]
# ================================================================================

# %% [markdown]
# ## Advanced NLP Approach: Using spaCy for Named Entity Recognition
#
# For even better extraction, we can use spaCy's NER to identify location entities (GPE - GeoPolitical Entity).
# This can help us extract city and country names more accurately from the review text.

# %%
# Optional: Enhanced extraction using spaCy (uncomment if you want to use it)
# You would need to install: pip install spacy
# And download model: python -m spacy download en_core_web_sm

"""
import spacy

# Load spaCy model
try:
    nlp = spacy.load('en_core_web_sm')
    
    def extract_route_with_spacy(text):
        if pd.isna(text):
            return None, None
        
        doc = nlp(str(text)[:1000])  # Limit text length for performance
        
        # Extract all location entities
        locations = [ent.text for ent in doc.ents if ent.label_ in ['GPE', 'LOC']]
        
        if len(locations) >= 2:
            return locations[0], locations[1]
        
        return None, None
    
    # Apply to records that weren't extracted by regex
    not_extracted_mask = mask_same_location & asr['NLP_extracted_origin'].isna()
    spacy_results = asr.loc[not_extracted_mask, 'Review_content'].apply(extract_route_with_spacy)
    
    print(f"Attempting spaCy extraction on {not_extracted_mask.sum()} remaining records...")
    print(f"This may take a while...")
    
except:
    print("spaCy not installed. Install with: pip install spacy")
    print("Then download model: python -m spacy download en_core_web_sm")
"""

print("To use advanced NLP with spaCy, uncomment the code above and install required packages.")
# Out:
# To use advanced NLP with spaCy, uncomment the code above and install required packages.

# %%
# Create a comprehensive summary dataframe
print("="*80)
print("COMPREHENSIVE SUMMARY OF NLP ROUTE EXTRACTION")
print("="*80)

# Breakdown by extraction status
summary_data = {
    'Category': [
        'Total Records',
        'Records with Same Start/End Address',
        'Successfully Extracted via NLP',
        'Unable to Extract (Need Manual Review)',
        'Records with Valid Routes (Original)'
    ],
    'Count': [
        len(asr),
        mask_same_location.sum(),
        successful_mask.sum(),
        mask_same_location.sum() - successful_mask.sum(),
        (asr['Route'].notna() & ~mask_same_location).sum()
    ]
}

summary_df = pd.DataFrame(summary_data)
print("\n", summary_df.to_string(index=False))

print(f"\n{'='*80}")
print("EXTRACTION PATTERNS BREAKDOWN:")
print(f"{'='*80}")
if successful_mask.sum() > 0:
    pattern_counts = asr[successful_mask]['NLP_extraction_method'].value_counts()
    for pattern, count in pattern_counts.items():
        print(f"  {pattern}: {count} records ({count/successful_mask.sum()*100:.1f}%)")

print(f"\n{'='*80}")
print("TOP EXTRACTED ROUTES:")
print(f"{'='*80}")
if successful_mask.sum() > 0:
    top_routes = asr[successful_mask]['Route'].value_counts().head(10)
    print(top_routes)

print(f"\n{'='*80}")
print("NEXT STEPS:")
print(f"{'='*80}")
print("1. ✓ Used NLP to extract routes from review text")
print(f"2. ✓ Successfully populated {successful_mask.sum()} routes from {mask_same_location.sum()} problematic records")
print(f"3. → {mask_same_location.sum() - successful_mask.sum()} records still need manual review or advanced NLP")
print("4. → Consider using the extracted data to update Start_Address and End_Address")
print("5. → Save the cleaned dataset with updated Route information")
print(f"{'='*80}")
# Out:
# ================================================================================
# COMPREHENSIVE SUMMARY OF NLP ROUTE EXTRACTION
# ================================================================================
#
#                                Category  Count
#                          Total Records   3501
#    Records with Same Start/End Address    694
#         Successfully Extracted via NLP    174
# Unable to Extract (Need Manual Review)    520
#   Records with Valid Routes (Original)   2807
#
# ================================================================================
# EXTRACTION PATTERNS BREAKDOWN:
# ================================================================================
#   from_to_pattern: 174 records (100.0%)
#
# ================================================================================
# TOP EXTRACTED ROUTES:
# ================================================================================
# Route
# Manchester-Heathrow       3
# London-Seattle            3
# Gatwick-Rome              2
# London-Calgary            2
# Singapore-London          2
# Venice-London             2
# Heathrow-Singapore        2
# Sydney-Singapore          2
# Barbados-London           2
# San Francisco-Heathrow    2
# Name: count, dtype: int64
#
# ================================================================================
# NEXT STEPS:
# ================================================================================
# 1. ✓ Used NLP to extract routes from review text
# 2. ✓ Successfully populated 174 routes from 694 problematic records
# 3. → 520 records still need manual review or advanced NLP
# 4. → Consider using the extracted data to update Start_Address and End_Address
# 5. → Save the cleaned dataset with updated Route information
# ================================================================================

# %%
# Helper function to get records by extraction status
def get_records_by_status(status='extracted'):
    """
    Get records based on NLP extraction status
    
    Parameters:
    - status: 'extracted' (successfully extracted), 
              'failed' (same start/end but couldn't extract),
              'problematic' (all records with same start/end),
              'valid' (records with different start/end)
    """
    if status == 'extracted':
        return asr[successful_mask].copy()
    elif status == 'failed':
        failed_mask = mask_same_location & asr['NLP_extracted_origin'].isna()
        return asr[failed_mask].copy()
    elif status == 'problematic':
        return asr[mask_same_location].copy()
    elif status == 'valid':
        return asr[~mask_same_location].copy()
    else:
        print("Invalid status. Use: 'extracted', 'failed', 'problematic', or 'valid'")
        return None

# Examples of how to use:
print("="*80)
print("HELPER FUNCTION: get_records_by_status()")
print("="*80)
print("\nUsage examples:")
print("  extracted_records = get_records_by_status('extracted')  # Successfully extracted")
print("  failed_records = get_records_by_status('failed')        # Failed to extract")
print("  all_problematic = get_records_by_status('problematic')  # All same start/end")
print("  valid_records = get_records_by_status('valid')          # Normal records")

print("\n" + "="*80)
print("Quick Stats:")
print("="*80)
print(f"Successfully extracted: {successful_mask.sum()} records")
print(f"Failed extraction: {(mask_same_location & asr['NLP_extracted_origin'].isna()).sum()} records")
print(f"Total problematic: {mask_same_location.sum()} records")
print(f"Valid records: {(~mask_same_location).sum()} records")
# Out:
# ================================================================================
# HELPER FUNCTION: get_records_by_status()
# ================================================================================
#
# Usage examples:
#   extracted_records = get_records_by_status('extracted')  # Successfully extracted
#   failed_records = get_records_by_status('failed')        # Failed to extract
#   all_problematic = get_records_by_status('problematic')  # All same start/end
#   valid_records = get_records_by_status('valid')          # Normal records
#
# ================================================================================
# Quick Stats:
# ================================================================================
# Successfully extracted: 174 records
# Failed extraction: 520 records
# Total problematic: 694 records
# Valid records: 2807 records

# %% [markdown]
# ## Final Answer: Rows Extracted via NLP
#
# **Summary:**
# - Out of **694 records** with same `Start_Address` and `End_Address`
# - **174 records (25.1%)** successfully had routes extracted from review content using NLP
# - **520 records (74.9%)** still need manual review or more advanced NLP
#
# **The 174 successfully extracted records** now have:
# - ✅ Updated `Route` field with format "Origin-Destination"
# - ✅ New columns: `NLP_extracted_origin`, `NLP_extracted_destination`, `NLP_extraction_method`
#
# **Access these records using:**
# ```python
# extracted_records = asr[successful_mask]
# # or
# extracted_records = get_records_by_status('extracted')
# ```

# %%
# Export the list of successfully extracted row indices for easy reference
extracted_row_indices = asr[successful_mask].index.tolist()

print("="*80)
print("COMPLETE LIST OF SUCCESSFULLY EXTRACTED ROW INDICES")
print("="*80)
print(f"\nTotal: {len(extracted_row_indices)} rows\n")
print(f"Indices: {extracted_row_indices}")

print("\n" + "="*80)
print("SAMPLE OF EXTRACTED DATA:")
print("="*80)
sample = asr[successful_mask][['Route', 'NLP_extracted_origin', 'NLP_extracted_destination', 
                                'Review_content']].head(5)
for idx, row in sample.iterrows():
    print(f"\nRow Index: {idx}")
    print(f"  Route: {row['Route']}")
    print(f"  Extracted: {row['NLP_extracted_origin']} → {row['NLP_extracted_destination']}")
    print(f"  Review: {str(row['Review_content'])[:100]}...")

print("\n" + "="*80)
print("✓ NLP extraction complete!")
print(f"✓ You can now work with {len(extracted_row_indices)} records with validated routes")
print("="*80)
# Out:
# ================================================================================
# COMPLETE LIST OF SUCCESSFULLY EXTRACTED ROW INDICES
# ================================================================================
#
# Total: 174 rows
#
# Indices: [2565, 2814, 2815, 2816, 2818, 2822, 2828, 2834, 2836, 2850, 2851, 2852, 2855, 2857, 2859, 2860, 2863, 2866, 2869, 2874, 2875, 2877, 2878, 2883, 2886, 2890, 2894, 2897, 2904, 2913, 2916, 2917, 2921, 2925, 2927, 2936, 2941, 2946, 2947, 2953, 2956, 2959, 2963, 2966, 2967, 2974, 2980, 2983, 2984, 2985, 2989, 2996, 3001, 3006, 3010, 3013, 3016, 3031, 3036, 3045, 3047, 3048, 3049, 3050, 3051, 3055, 3058, 3059, 3060, 3063, 3087, 3101, 3104, 3118, 3123, 3126, 3132, 3135, 3140, 3141, 3145, 3154, 3157, 3165, 3168, 3171, 3174, 3180, 3181, 3191, 3206, 3208, 3211, 3215, 3216, 3218, 3220, 3225, 3227, 3229, 3244, 3245, 3250, 3253, 3265, 3275, 3278, 3280, 3282, 3284, 3285, 3290, 3295, 3296, 3301, 3302, 3303, 3308, 3314, 3319, 3323, 3327, 3335, 3339, 3340, 3341, 3345, 3346, 3347, 3350, 3351, 3361, 3363, 3365, 3366, 3368, 3369, 3374, 3377, 3381, 3382, 3383, 3386, 3393, 3394, 3396, 3399, 3400, 3401, 3404, 3406, 3417, 3419, 3428, 3432, 3434, 3435, 3436, 3445, 3451, 3454, 3461, 3465, 3466, 3467, 3469, 3476, 3477, 3491, 3493, 3495, 3496, 3497, 3498]
#
# ================================================================================
# SAMPLE OF EXTRACTED DATA:
# ================================================================================
#
# Row Index: 2565
#   Route: London-The
#   Extracted: london → the
#   Review: The British Airways seats were extremely small, uncomfortable and did not operate properly. In order...
#
# Row Index: 2814
#   Route: Venice-Gatwick
#   Extracted: venice → gatwick
#   Review: Travelled from Venice to Gatwick on 28th May check in staff rude and unhelpful plane seats and food ...
#
# Row Index: 2815
#   Route: Singapore-Sydney
#   Extracted: singapore → sydney
#   Review: Worst customer experience on BA flight. I have a confirmed flights for British Airways from Singapor...
#
# Row Index: 2816
#   Route: Heathrow-Calgary
#   Extracted: heathrow → calgary
#   Review: I had this terrible experience of traveling British Airways from Heathrow to Calgary. The plane was ...
#
# Row Index: 2818
#   Route: Heathrow-Tokyo
#   Extracted: heathrow → tokyo
#   Review: I flew from Heathrow to Tokyo Haneda in First. The Concorde Lounge at Heathrow was quite good though...
#
# ================================================================================
# ✓ NLP extraction complete!
# ✓ You can now work with 174 records with validated routes
# ================================================================================
